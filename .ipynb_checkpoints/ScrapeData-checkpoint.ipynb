# %%
import requests
import re
from bs4 import BeautifulSoup as bs4
import pandas as pd
import numpy as np
import nltk
from tqdm import tqdm
pd.set_option('display.max_rows', None)

# %%
def ScrapeSongsOfYear(YearSongsURL):
    page = requests.get(YearSongsURL)
    soup = bs4(page.content, 'html.parser')
    section = soup.find(class_='mw-parser-output')
    table = section.find('table',{"class":"wikitable sortable"}) #specific table
    body = table.find('tbody')
    rows = body.find_all('tr')
    row = body.find_all('td')

    return row

# %%
def ExtractData(data):
    df = pd.DataFrame(columns=["Index","Song","Artist","Genre"])
    links = []
    titleAndName = []
    
    for row in data:
        link_elem = row.find('a')
        info = row.get_text().strip()
        titleAndName.append(info)
        if link_elem is None: 
            links.append("NoneType") # If no link on artist/song
        else:
            link = link_elem.get('href')
            links.append("https://en.wikipedia.org"+link)
    
    df["Index"]= titleAndName[::3]
    df["Song"]=titleAndName[1::3]
    df["Artist"]=titleAndName[2::3]
    
    songlink = links[1::3]
    artistlink = links[2::3]

    return df,songlink,artistlink

# %%
#extract just the pronouns from a text
nltk.download('punkt') # download the necessary nltk data

def extract_pronouns(text):
    # Tokenize the text into sentences
    sentences = nltk.sent_tokenize(text)
    
    # Use nltk's POS tagging to tag the parts of speech in each sentence
    tagged_sentences = [nltk.pos_tag(nltk.word_tokenize(sentence)) for sentence in sentences]
    
    # Extract the pronouns from the tagged sentences
    pronouns = []
    for tagged_sentence in tagged_sentences:
        for word, pos in tagged_sentence:
#             print(word,pos)
            if pos == 'PRP' or pos == 'PRP$' or word == "band" or word=="collaboration":
                pronouns.append(word.lower())
    
    keep_list =['she','her','band','collaboration','him','his','he']
    for p in pronouns:
        if p not in keep_list:
            pronouns.remove(p)
    
    return pronouns
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/angeleparkcollin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def getArtistGender(links):
    genders =[]
    for link in links:
        if link == "NoneType": # ie. No link
            genders.append('Unknown')
            continue
        page = requests.get(link)
        soup = bs4(page.content, 'html.parser')
        section = soup.find(class_='mw-body-content mw-content-ltr')

        intro = section.find_all('p')[1].text
        
        if len(intro) < 5:
            intro = section.find_all('p')[2].text
        pronouns = extract_pronouns(intro)
        if len(pronouns) == 0:
            pronouns = ['Unknown']
        
        if pronouns[0] == "she" or pronouns[0] == "her":
            genders.append('Female')
        elif pronouns[0] == "his" or pronouns[0] == "him" or pronouns[0]== 'he':
            genders.append('Male')
        elif pronouns[0] =='band' or pronouns[0] =='collaboration':
            genders.append('Group')
        else:
            genders.append('Unknown')

    return genders

# %%
def getSongGenre(links, df, start_index=0):
    for link in links:
        page = requests.get(link)
        soup = bs4(page.content, 'html.parser')
        table = soup.find('table', class_='infobox').find('th', string='Genre') 
        if table is None:
            df.loc[start_index, "Genre"] = "None"
        else:
            genres = table.find_parent('tr').find('td')
            genre_names = [genre.strip() for genre in genres.text.split('\n') if genre.strip()]
            superscript_pattern = r'\[\d+\]'
            genre_names = [re.sub(superscript_pattern, '', text) for text in genre_names]
            df.loc[start_index, "Genre"] = genre_names[0]
            
        start_index += 1
    return df

# %%
#Rescrapre from wikipedia
Y2022="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2022"
Y2012="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2012"
Y2002="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2002"
Y1992="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1992"
Y1982="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1982"
Y1972="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1972"
Y1962="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1962"
Y1952="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1952"
Y1942="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1942"
# years = [Y2022,Y2012,Y2002,Y1992,Y1982,Y1972,Y1962,Y1952,Y1942]
years = [Y2022,Y2012]
for year in years:
    data = ScrapeSongsOfYear(year)
    df,songlinks,artistlink = ExtractData(data)
    genders = getArtistGender(artistlink)
    df['Genders'] = pd.Series(genders)
    getSongGenre(songlinks,df)

    # Put df into csv file
    df.to_csv('songsOfYear.csv', mode='a', index=False, header=False)

# %%
# df,songlinks,artistlink = ExtractData(data)

# %%
# genders = getArtistGender(artistlink)
# df['Genders'] = pd.Series(genders)

# %%
# getSongGenre(songlinks,df)
# Out:
#    Index                                               Song  \
# 0      1                     "Somebody That I Used to Know"
# 1      2                                    "Call Me Maybe"
# 2      3                                     "We Are Young"
# 3      4                                         "Payphone"
# 4      5                                           "Lights"
# 5      6                                    "Glad You Came"
# 6      7                 "Stronger (What Doesn't Kill You)"
# 7      8                                    "We Found Love"
# 8      9                                        "Starships"
# 9     10                         "What Makes You Beautiful"
# 10    11                                        "Wild Ones"
# 11    12                             "Set Fire to the Rain"
# 12    13                               "Sexy and I Know It"
# 13    14                                      "Some Nights"
# 14    15                                       "Wide Awake"
# 15    16                                     "Good Feeling"
# 16    17                                          "Whistle"
# 17    18                                   "One More Night"
# 18    19                                         "Drive By"
# 19    20                                        "The Motto"
# 20    21                              "Where Have You Been"
# 21    22                                  "Everybody Talks"
# 22    23                                        "Take Care"
# 23    24                                         "Titanium"
# 24    25                                  "I Won't Give Up"
# 25    26                                     "It Will Rain"
# 26    27                                            "Mercy"
# 27    28                                        "Boyfriend"
# 28    29                                "Party Rock Anthem"
# 29    30                                        "Too Close"
# 30    31                                       "Part of Me"
# 31    32                               "Young, Wild & Free"
# 32    33          "We Are Never Ever Getting Back Together"
# 33    34                           "As Long as You Love Me"
# 34    35                                       "Turn Me On"
# 35    36                                "Moves like Jagger"
# 36    37                          "Blow Me (One Last Kiss)"
# 37    38                                        "Good Time"
# 38    39                          "Give Your Heart a Break"
# 39    40                                  "Niggas in Paris"
# 40    41                            "The One That Got Away"
# 41    42                                    "Feel So Close"
# 42    43                                 "Someone like You"
# 43    44                                           "Scream"
# 44    45                                        "Rack City"
# 45    46                                           "Domino"
# 46    47                                    "Gangnam Style"
# 47    48                               "International Love"
# 48    49                                             "Home"
# 49    50                                      "Without You"
# 50    51                                    "Ass Back Home"
# 51    52                                           "Wanted"
# 52    53                                     "Drunk on You"
# 53    54                                           "No Lie"
# 54    55                                      "Want U Back"
# 55    56                                 "Don't Wake Me Up"
# 56    57                                      "Dance (A$$)"
# 57    58                                      "Springsteen"
# 58    59                                    "Brokenhearted"
# 59    60                                     "Not Over You"
# 60    61                                    "Stereo Hearts"
# 61    62                                     "Back in Time"
# 62    63                                         "Work Out"
# 63    64                                    "Rumour Has It"
# 64    65                                         "Let's Go"
# 65    66                                        "Good Girl"
# 66    67                                          "Pontoon"
# 67    68                                           "Ho Hey"
# 68    69                                         "Paradise"
# 69    70                                       "Blown Away"
# 70    71                              "Rolling in the Deep"
# 71    72                                           "Climax"
# 72    73                             "Work Hard, Play Hard"
# 73    74  "Let Me Love You (Until You Learn to Love Your...
# 74    75                                  "Pound the Alarm"
# 75    76                                        "Come Over"
# 76    77                                     "Heart Attack"
# 77    78                                  "Drank in My Cup"
# 78    79                                    "Birthday Cake"
# 79    80                                          "So Good"
# 80    81                           "50 Ways to Say Goodbye"
# 81    82                                     "Red Solo Cup"
# 82    83                        "Love You like a Love Song"
# 83    84                                "Turn Up the Music"
# 84    85                                        "Die Young"
# 85    86                                        "5 O'Clock"
# 86    87                                 "A Thousand Years"
# 87    88                               "Take a Little Ride"
# 88    89                                       "You da One"
# 89    90                                 "We Run the Night"
# 90    91                                        "It's Time"
# 91    92                                      "Cashin' Out"
# 92    93                   "I Don't Want This Night to End"
# 93    94                                         "Diamonds"
# 94    95                                     "Hard to Love"
# 95    96                          "Somethin' 'Bout a Truck"
# 96    97                                            "Adorn"
# 97    98                                  "Fly Over States"
# 98    99                     "Even If It Breaks Your Heart"
# 99   100                                     "Burn It Down"
#
#                                              Artist  \
# 0                            Gotye featuring Kimbra
# 1                                  Carly Rae Jepsen
# 2                       Fun featuring Janelle Monáe
# 3                    Maroon 5 featuring Wiz Khalifa
# 4                                    Ellie Goulding
# 5                                        The Wanted
# 6                                    Kelly Clarkson
# 7                   Rihanna featuring Calvin Harris
# 8                                       Nicki Minaj
# 9                                     One Direction
# 10                           Flo Rida featuring Sia
# 11                                            Adele
# 12                                            LMFAO
# 13                                              Fun
# 14                                       Katy Perry
# 15                                         Flo Rida
# 16                                         Flo Rida
# 17                                         Maroon 5
# 18                                            Train
# 19                        Drake featuring Lil Wayne
# 20                                          Rihanna
# 21                                       Neon Trees
# 22                          Drake featuring Rihanna
# 23                       David Guetta featuring Sia
# 24                                       Jason Mraz
# 25                                       Bruno Mars
# 26       Kanye West, Big Sean, Pusha T and 2 Chainz
# 27                                    Justin Bieber
# 28      LMFAO featuring Lauren Bennett and GoonRock
# 29                                       Alex Clare
# 30                                       Katy Perry
# 31  Snoop Dogg and Wiz Khalifa featuring Bruno Mars
# 32                                     Taylor Swift
# 33                 Justin Bieber featuring Big Sean
# 34               David Guetta featuring Nicki Minaj
# 35            Maroon 5 featuring Christina Aguilera
# 36                                             Pink
# 37                    Owl City and Carly Rae Jepsen
# 38                                      Demi Lovato
# 39                             Jay-Z and Kanye West
# 40                                       Katy Perry
# 41                                    Calvin Harris
# 42                                            Adele
# 43                                            Usher
# 44                                             Tyga
# 45                                         Jessie J
# 46                                              Psy
# 47                    Pitbull featuring Chris Brown
# 48                                 Phillip Phillips
# 49                     David Guetta featuring Usher
# 50            Gym Class Heroes featuring Neon Hitch
# 51                                     Hunter Hayes
# 52                                       Luke Bryan
# 53                         2 Chainz featuring Drake
# 54                                       Cher Lloyd
# 55                                      Chris Brown
# 56                   Big Sean featuring Nicki Minaj
# 57                                      Eric Church
# 58                                           Karmin
# 59                                     Gavin DeGraw
# 60           Gym Class Heroes featuring Adam Levine
# 61                                          Pitbull
# 62                                          J. Cole
# 63                                            Adele
# 64                    Calvin Harris featuring Ne-Yo
# 65                                 Carrie Underwood
# 66                                  Little Big Town
# 67                                    The Lumineers
# 68                                         Coldplay
# 69                                 Carrie Underwood
# 70                                            Adele
# 71                                            Usher
# 72                                      Wiz Khalifa
# 73                                            Ne-Yo
# 74                                      Nicki Minaj
# 75                                    Kenny Chesney
# 76                                       Trey Songz
# 77                                      Kirko Bangz
# 78                    Rihanna featuring Chris Brown
# 79                                            B.o.B
# 80                                            Train
# 81                                       Toby Keith
# 82                         Selena Gomez & the Scene
# 83                                      Chris Brown
# 84                                            Kesha
# 85      T-Pain featuring Wiz Khalifa and Lily Allen
# 86                                  Christina Perri
# 87                                     Jason Aldean
# 88                                          Rihanna
# 89                   Havana Brown featuring Pitbull
# 90                                  Imagine Dragons
# 91                                         Cash Out
# 92                                       Luke Bryan
# 93                                          Rihanna
# 94                                        Lee Brice
# 95                                        Kip Moore
# 96                                           Miguel
# 97                                     Jason Aldean
# 98                                   Eli Young Band
# 99                                      Linkin Park
#
#                               Genre  Genders
# 0                           Art pop     Male
# 1                               Pop   Female
# 2   Stadium rockindie rockindie pop    Group
# 3                               Pop    Group
# 4                         Synth-pop   Female
# 5                         Eurodance    Group
# 6                         Dance-pop   Female
# 7            Electro housedance-pop   Female
# 8                         Dance-pop   Female
# 9                         Power pop    Group
# 10                        Dance-pop     Male
# 11                        Power pop   Female
# 12                       Electropop     Male
# 13                 Alternative rock    Group
# 14                        Dance-pop   Female
# 15                        Hip house     Male
# 16                       Electropop     Male
# 17                              Pop    Group
# 18                         Pop rock    Group
# 19                          Hip hop     Male
# 20        Electro housetrancetechno   Female
# 21                         Pop rock  Unknown
# 22                             Club     Male
# 23                       Housedance     Male
# 24                    Folk bluespop     Male
# 25                              Pop     Male
# 26                          Hip hop  Unknown
# 27                             None     Male
# 28                       Electropop     Male
# 29                     R&B, Dubstep     Male
# 30               Dance-poppower pop   Female
# 31                          Pop-rap     Male
# 32                              Pop   Female
# 33                Electropopdubstep     Male
# 34                              EDM     Male
# 35                         Nu-disco    Group
# 36                       Electropop   Female
# 37                        Dance-pop     Male
# 38                         Pop, R&B  Unknown
# 39                          Hip hop     Male
# 40                              Pop   Female
# 41           Electro housedance-pop  Unknown
# 42                              Pop   Female
# 43                       Techno-pop     Male
# 44                          Hip hop     Male
# 45                       Electropop   Female
# 46                            K-pop     Male
# 47                        Dance-pop     Male
# 48                        Folk rock     Male
# 49                             None     Male
# 50                          Pop-rap    Group
# 51               Countrycountry pop     Male
# 52                          Country     Male
# 53                      Hip hoptrap     Male
# 54                              Pop   Female
# 55                   Dance-pop, EDM     Male
# 56                          Hip hop     Male
# 57            Countryheartland rock     Male
# 58                        Dance-pop  Unknown
# 59           Pop rockblue-eyed soul     Male
# 60                          Pop-rap    Group
# 61                     Dancedubstep     Male
# 62                       Hip hopR&B     Male
# 63                     Bluespopjazz   Female
# 64                             None  Unknown
# 65                     Country rock   Female
# 66                          Country  Unknown
# 67      Folk rock, alternative rock    Group
# 68                 Alternative rock    Group
# 69                      Country pop   Female
# 70             Rhythm and bluessoul   Female
# 71                      Quiet storm     Male
# 72                          Hip hop     Male
# 73        Europopdance-popsynth-pop     Male
# 74                        Eurodance   Female
# 75                          Country     Male
# 76                              R&B     Male
# 77     Pop-rap, chopped and screwed     Male
# 78                              R&B   Female
# 79                          Pop-rap     Male
# 80                         Pop rock    Group
# 81                          Country     Male
# 82              Electropopdance-pop    Group
# 83                    Electro house     Male
# 84              Electropopdance-pop   Female
# 85                       Hip hopR&B     Male
# 86                             None   Female
# 87                          Country     Male
# 88                              Pop   Female
# 89               Dance-popEurodance   Female
# 90                 Alternative rock    Group
# 91                          Hip hop     Male
# 92                          Country     Male
# 93                              Pop   Female
# 94                          Country     Male
# 95            Country, country rock     Male
# 96                  R&Belectro soul     Male
# 97                          Country     Male
# 98                          Country  Unknown
# 99                  Electronic rock    Group

# %%
# # Put df into csv file
# df.to_csv("songsofYear.csv", index=False)
