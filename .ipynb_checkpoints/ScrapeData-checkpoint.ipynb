# %%
# Imports
import requests
import re
from bs4 import BeautifulSoup as bs4
import pandas as pd
import numpy as np
import nltk
pd.set_option('display.max_rows', None)

# %%
'''
Function -> ScrapeSongsOfYear() Scraping the section of the website needed and outputing the value 
    to continue working on it to avoid overloading server. The part of the website being scraped is 
    the year-end List table containing the Number the song ranked, the title of the song, and the artist.
    
(Input): A string URL of the website to scrape 
(Output): HTML to parse consisting of a list of 300 <td></td> tags.
        <td> number the song ranked </td>
        <td> song title </td>
        <td> song artist</td>
'''
def ScrapeSongsOfYear(YearSongsURL):
    page = requests.get(YearSongsURL)
    # Checking status code
    if page.status_code != 200: 
        return False
    soup = bs4(page.content, 'html.parser')
    section = soup.find(class_='mw-parser-output')
    table = section.find('table',{"class":"wikitable sortable"}) #specific table
    body = table.find('tbody')
    rows = body.find_all('tr')
    row = body.find_all('td')

    return row

# %%
'''
Function -> ExtractData() Parses the html and puts the information scraped into a dataframe. 
            Also takes the urls hyperlinked to the song name and artist name and appends them into a list.
            It accounts for when the song title or song artist has no link.
            
(Input): HTML list outputted from ScrapeSongsOfYear().
(Output): A df consisting of the Billboard Hit Number, the song title and the artist name.
          A list of URLs consisting of the song wikipedia page that was linked
          A list of URLs consisting of the artist wikipedia page that was linked
'''
def ExtractData(data):
    df = pd.DataFrame(columns=["Billboard Hit Number","Song","Artist","Genre"])
    links = []
    titleAndName = []
    
    for row in data:
        link_elem = row.find('a')
        info = row.get_text().strip()
        titleAndName.append(info)
        # If no link on artist/song, set as None to be able to correctly slice indices
        if link_elem is None: 
            links.append("NoneType") 
        else:
            link = link_elem.get('href')
            links.append("https://en.wikipedia.org"+link)
    
    df["Billboard Hit Number"]= titleAndName[::3] # Slice every 3rd element starting at 0th index (Hit Number)
    df["Song"]=titleAndName[1::3] # Slice every 3rd element starting at 1st index (Song title)
    df["Artist"]=titleAndName[2::3] # Slice every 3rd element starting at 2nd index (Song Artist)
    
    songlink = links[1::3]
    artistlink = links[2::3]

    return df,songlink,artistlink

# %%
'''
Function -> ExtractPronouns() Extracts the pronouns from a text scraped from the Artists wikipedia page to be 
            able to label the gender of the artist
            
(Input): HTML text from getArtistGender() function
(Output): A list of pronouns extracted from the text 
'''
# Extract just the pronouns from a text
nltk.download('punkt') 
def ExtractPronouns(text):
    sentences = nltk.sent_tokenize(text)
    # Tag the parts of speech in each sentence 
    tagged_sentences = [nltk.pos_tag(nltk.word_tokenize(sentence)) for sentence in sentences]
    
    # Extract the pronouns from the tagged sentences
    pronouns = []
    for tagged_sentence in tagged_sentences:
        for word, pos in tagged_sentence:
            if pos == 'PRP' or pos == 'PRP$' or word == "band" or word=="collaboration" or word=="group":
                pronouns.append(word.lower())
                
    # Only keep the word if its one of the below
    keep_list =['she','her','band','collaboration','group','him','his','he']
    for p in pronouns:
        if p not in keep_list:
            pronouns.remove(p)
    
    return pronouns
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/angeleparkcollin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
'''
Function -> getArtistGender() Scrapes the Gender of the artist by grabbing the introduction part of the text 
            on each wikipedia page. Then uses the ExtractPronouns function to extract just the pronouns in the 
            text to be able to label the artist more precisely.
            
(Input): A list of URLs of artist wikipedia pages
(Output): A list of the gender of each artist. 
'''
def getArtistGender(links):
    genders =[]
    for link in links:
        if link == "NoneType": # ie. No link attached to Artist name in the Billboard hits page
            genders.append('Unknown')
            continue
        page = requests.get(link)
        soup = bs4(page.content, 'html.parser')
        section = soup.find(class_='mw-body-content mw-content-ltr')

        intro = section.find_all('p')[1].text
        # If the intro is too short/non existent the grab the second section of the wikipedia text 
        if len(intro) < 5:
            intro = section.find_all('p')[2].text
        pronouns = ExtractPronouns(intro)
        if len(pronouns) == 0:
            pronouns = ['Unknown']
        # From the list outputted by ExtractPronouns function, take the first element and label as 'Female','Male','Group' accordingly.
        if pronouns[0] == "she" or pronouns[0] == "her":
            genders.append('Female')
        elif pronouns[0] == "his" or pronouns[0] == "him" or pronouns[0]== 'he':
            genders.append('Male')
        elif pronouns[0] =='band' or pronouns[0] =='collaboration'or pronouns[0] =='group':
            genders.append('Group')
        else:
            genders.append('Unknown')

    return genders

# %%
def getSongGenre(links, df, start_index=0):
    for link in links:
        if link == "NoneType": # ie. No link
            df.loc[start_index, "Genre"] = "None"
            continue
        page = requests.get(link)
        soup = bs4(page.content, 'html.parser')
        table = soup.find('table', class_='infobox')
        if table is None:
            df.loc[start_index, "Genre"] = "None"
        else:
            box = table.find('th', string='Genre') 
            if box is None:
                df.loc[start_index, "Genre"] = "None"
            else:
                genres = box.find_parent('tr').find('td')
                genre_names = [genre.strip() for genre in genres.text.split('\n') if genre.strip()]
                superscript_pattern = r'\[\d+\]'
                genre_names = [re.sub(superscript_pattern, '', text) for text in genre_names]
                df.loc[start_index, "Genre"] = genre_names[0]
            
        start_index += 1
    return df

# %%
'''
Function -> getSongGenre() Scrapes the song Genre by grabbing the genre section on the info box on each 
            wikipedia page. Takes just the first genre indicated as its the most common genre of the song.
            If theres no link then set Genre as none or if theres no infobox (1950s-1970s) then set as none. 
            
(Input): A list of URLs of song wikipedia pages, a dataframe{Billboard hit number, song, artist, genre, gender}, 
         and a start_index=0 to fill the dataframe at the correct index.
(Output): A dataframe filling out the song Genre column of the dataframe
'''
def getSongGenre(links, df, start_index=0):
    for link in links:
        if link == "NoneType": # ie. No link
            df.loc[start_index, "Genre"] = "None"
            start_index += 1
            continue
        page = requests.get(link)
        soup = bs4(page.content, 'html.parser')
        table = soup.find('table', class_='infobox')
        if table is None:
            df.loc[start_index, "Genre"] = "None"
        else:
            box = table.find('th', string='Genre') 
            if box is None:
                df.loc[start_index, "Genre"] = "None"
            else:
                genres = box.find_parent('tr').find('td')
                genre_names = [genre.strip() for genre in genres.text.split('\n') if genre.strip()]
                superscript_pattern = r'\[\d+\]'
                genre_names = [re.sub(superscript_pattern, '', text) for text in genre_names]
                df.loc[start_index, "Genre"] = genre_names[0]
            
        start_index += 1
    return df

# %%
# Run main - will take a while to run all ~ 15 mins?
'''
Run main() to get the combined dataframe of all the data the hits every decade from 1952-2022
Uncomment df.to_csv to start appending to file. I recommend changing the file name as it was append not overrite
'''
def main():
    # Scrape from wikipedia
    Y2022="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2022" #100 songs
    Y2012="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2012" #100 songs
    Y2002="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2002" #100 songs
    Y1992="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1992" #100 songs
    Y1982="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1982" #100 songs
    Y1972="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1972" #100 songs
    Y1962="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1962" #100 songs
    Y1952="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1952" #30 songs
    years = [Y2022,Y2012,Y2002,Y1992,Y1982,Y1972,Y1962,Y1952]
    for year in years:
        data = ScrapeSongsOfYear(year)
        df,songlinks,artistlink = ExtractData(data)
        genders = getArtistGender(artistlink)
        df['Genders'] = pd.Series(genders)
        getSongGenre(songlinks,df)
        display(df)
        # Append each df into csv file
#         df.to_csv('songsOfYear.csv', mode='a', index=False, header=False)

if __name__ == "__main__":
    main()
# Out:
#    Billboard Hit Number                                               Song  \
# 0                     1                            "Stranger on the Shore"
# 1                     2                          "I Can't Stop Loving You"
# 2                     3                               "Mashed Potato Time"
# 3                     4                          "Roses Are Red (My Love)"
# 4                     5                                     "The Stripper"
# 5                     6                                     "Johnny Angel"
# 6                     7                                  "The Loco-Motion"
# 7                     8                                        "Let Me In"
# 8                     9                                        "The Twist"
# 9                    10                                      "Soldier Boy"
# 10                   11                                        "Hey! Baby"
# 11                   12                                     "The Wanderer"
# 12                   13                                     "Duke of Earl"
# 13                   14                                   "Palisades Park"
# 14                   15                        "Breaking Up Is Hard to Do"
# 15                   16                               "Wolverton Mountain"
# 16                   17                                    "Slow Twistin'"
# 17                   18                      "It Keeps Right On a-Hurtin'"
# 18                   19                     "The One Who Really Loves You"
# 19                   20                                  "Good Luck Charm"
# 20                   21                               "Midnight in Moscow"
# 21                   22                                           "Sheila"
# 22                   23                          "Twistin' the Night Away"
# 23                   24                                   "The Wah-Watusi"
# 24                   25                                 "Peppermint Twist"
# 25                   26                            "Break It to Me Gently"
# 26                   27                                          "Playboy"
# 27                   28                                    "Ramblin' Rose"
# 28                   29                               "Sealed with a Kiss"
# 29                   30                                        "She Cried"
# 30                   31             "Don't Break the Heart That Loves You"
# 31                   32                                  "Dear Lady Twist"
# 32                   33                                           "Norman"
# 33                   34                                     "Love Letters"
# 34                   35                                     "Party Lights"
# 35                   36                                    "Cotton Fields"
# 36                   37                                        "Alley Cat"
# 37                   38                                  "Twist and Shout"
# 38                   39  "Theme from Dr. Kildare (Three Stars Will Shin...
# 39                   40                                             "Tuff"
# 40                   41                                     "Lover Please"
# 41                   42               "I Know (You Don't Love Me No More)"
# 42                   43                                      "Young World"
# 43                   44                                    "Baby It's You"
# 44                   45                                  "Speedy Gonzales"
# 45                   46                              "A Little Bitty Tear"
# 46                   47                               "Crying in the Rain"
# 47                   48                                         "Al di là"
# 48                   49               "Shout! Shout! (Knock Yourself Out)"
# 49                   50                                 "What's Your Name"
# 50                   51                                     "Smoky Places"
# 51                   52                                   "Having a Party"
# 52                   53                                     "Green Onions"
# 53                   54                                "You Don't Know Me"
# 54                   55                                           "Sherry"
# 55                   56                                 "Johnny Get Angry"
# 56                   57                       "Can't Help Falling in Love"
# 57                   58                                            "Shout"
# 58                   59                                       "Rinky Dink"
# 59                   60                                       "Moon River"
# 60                   61                                    "Ahab the Arab"
# 61                   62                                           "Things"
# 62                   63               "(The Man Who Shot) Liberty Valance"
# 63                   64                                 "You Belong to Me"
# 64                   65               "Dream Baby (How Long Must I Dream)"
# 65                   66                                "Snap Your Fingers"
# 66                   67                                "Lovers Who Wander"
# 67                   68                                      "Let's Dance"
# 68                   69                                 "Cindy's Birthday"
# 69                   70                         "You Beat Me to the Punch"
# 70                   71                         "You'll Lose a Good Thing"
# 71                   72                                           "Uptown"
# 72                   73                       "Everybody Loves Me But You"
# 73                   74                                          "Patches"
# 74                   75                              "Venus in Blue Jeans"
# 75                   76                          "Love Me Warm and Tender"
# 76                   77                                    "Teen Age Idol"
# 77                   78                                    "She's Got You"
# 78                   79                                         "Dear One"
# 79                   80                                "Her Royal Majesty"
# 80                   81                                       "Old Rivers"
# 81                   82                            "Funny Way of Laughin'"
# 82                   83                                "A Swingin' Safari"
# 83                   84                                          "Tell Me"
# 84                   85                                           "PT-109"
# 85                   86                                     "Little Diane"
# 86                   87                               "Percolator (Twist)"
# 87                   88                              "Twist, Twist Senora"
# 88                   89                                 "Twistin' Matilda"
# 89                   90                   "Gravy (For My Mashed Potatoes)"
# 90                   91                            "Walk on the Wild Side"
# 91                   92                                       "Soul Twist"
# 92                   93                           "I'll Never Dance Again"
# 93                   94                    "I'm Blue (The Gong-Gong Song)"
# 94                   95                 "Where Have All the Flowers Gone?"
# 95                   96               "(Girls, Girls, Girls) Made to Love"
# 96                   97                                "Town Without Pity"
# 97                   98                                "If I Had a Hammer"
# 98                   99                      "I Wish That We Were Married"
# 99                  100                                   "Surfin' Safari"
#
#                             Artist                                Genre  \
# 0                       Acker Bilk                Easy listening • Jazz
# 1                      Ray Charles                              Country
# 2                    Dee Dee Sharp                             R&B, pop
# 3                     Bobby Vinton                                  Pop
# 4                       David Rose                                 Jazz
# 5                  Shelley Fabares                                  Pop
# 6                       Little Eva                Pop, rhythm and blues
# 7                   The Sensations                                 None
# 8                   Chubby Checker                   Rock and roll, pop
# 9                    The Shirelles                                  R&B
# 10                   Bruce Channel                                  Pop
# 11                            Dion                     Rhythm and blues
# 12                   Gene Chandler                         R&B, doo-wop
# 13                   Freddy Cannon                        Rock and roll
# 14                     Neil Sedaka              Brill Building, doo-wop
# 15                     Claude King                              Country
# 16  Chubby Checker & Dee Dee Sharp                 R&Brock and rollsoul
# 17                Johnny Tillotson                              Country
# 18                      Mary Wells                                 Soul
# 19                   Elvis Presley                     Rock and rollpop
# 20                      Kenny Ball                                 None
# 21                       Tommy Roe  Pop rock, rockabilly, Lubbock sound
# 22                       Sam Cooke                     Rhythm and blues
# 23                      The Orlons                                  R&B
# 24     Joey Dee and the Starliters                        Rock and roll
# 25                      Brenda Lee                       Vocal, country
# 26                 The Marvelettes                     Rhythm and blues
# 27                   Nat King Cole                                 None
# 28                    Brian Hyland                                  Pop
# 29           Jay and the Americans                                 Rock
# 30                  Connie Francis                              Country
# 31                 Gary U.S. Bonds                        Rock and roll
# 32                    Sue Thompson                                 None
# 33                    Ketty Lester                                  Pop
# 34                  Claudine Clark                                  R&B
# 35                  The Highwaymen                                 None
# 36                     Bent Fabric                                  Pop
# 37              The Isley Brothers                        Rock and roll
# 38             Richard Chamberlain                                 None
# 39                      Ace Cannon                           Blues rock
# 40                 Clyde McPhatter                        Rock and roll
# 41                  Barbara George                                  R&B
# 42                    Ricky Nelson                               Ballad
# 43                   The Shirelles                                 None
# 44                       Pat Boone                                  Pop
# 45                       Burl Ives        Country, pop, Nashville sound
# 46             The Everly Brothers                                 None
# 47                 Emilio Pericoli                                 None
# 48                   Ernie Maresca               Rock and roll, doo-wop
# 49                    Don and Juan                                 None
# 50                    The Corsairs                              Doo-wop
# 51                       Sam Cooke               Rhythm and blues, soul
# 52          Booker T. & the M.G.'s             Instrumental rocksoulR&B
# 53                     Ray Charles                              Country
# 54                The Four Seasons                   Doo-woppoppop rock
# 55                  Joanie Sommers                                  Pop
# 56                   Elvis Presley                                  Pop
# 57     Joey Dee and the Starliters                        Rock and roll
# 58              Dave "Baby" Cortez                                  Pop
# 59                   Henry Mancini                      Traditional pop
# 60                     Ray Stevens                              Novelty
# 61                     Bobby Darin                             Pop rock
# 62                     Gene Pitney                          Country pop
# 63                     The Duprees              Ballad, traditional pop
# 64                     Roy Orbison                           Rockabilly
# 65                   Joe Henderson                                  R&B
# 66                            Dion                        Rock and roll
# 67                    Chris Montez           Rock and roll, garage rock
# 68                 Johnny Crawford                                 None
# 69                      Mary Wells                                 Soul
# 70                    Barbara Lynn                     Rhythm and blues
# 71                    The Crystals                                 None
# 72                      Brenda Lee                                Vocal
# 73                      Dickey Lee                                  Pop
# 74                   Jimmy Clanton                                 None
# 75                       Paul Anka                                 None
# 76                     Rick Nelson                                  Pop
# 77                     Patsy Cline                       Countrypolitan
# 78                  Larry Finnegan                                  Pop
# 79                    James Darren                        Rock and roll
# 80                  Walter Brennan                              Country
# 81                       Burl Ives                                 Folk
# 82                    Billy Vaughn                                 None
# 83                Dick and Dee Dee                                 None
# 84                      Jimmy Dean                          Country Pop
# 85                            Dion                        Rock and roll
# 86    Billy Joe and the Checkmates                                 None
# 87                 Gary U.S. Bonds                        Rock and roll
# 88                      Jimmy Soul                                 None
# 89                   Dee Dee Sharp                                 None
# 90                     Jimmy Smith                                 None
# 91                     King Curtis                                  R&B
# 92                    Bobby Rydell                                  Pop
# 93                     The Ikettes                            R&B, Soul
# 94               The Kingston Trio                                 None
# 95                    Eddie Hodges                                 None
# 96                     Gene Pitney                                 None
# 97            Peter, Paul and Mary                                 Folk
# 98           Ronnie & the Hi-Lites                                 None
# 99                  The Beach Boys                            Surf rock
#
#     Genders
# 0      Male
# 1      Male
# 2    Female
# 3      Male
# 4      Male
# 5    Female
# 6    Female
# 7     Group
# 8      Male
# 9     Group
# 10     Male
# 11     Male
# 12     Male
# 13     Male
# 14     Male
# 15     Male
# 16     Male
# 17     Male
# 18  Unknown
# 19     Male
# 20     Male
# 21     Male
# 22     Male
# 23  Unknown
# 24    Group
# 25   Female
# 26    Group
# 27     Male
# 28     Male
# 29    Group
# 30   Female
# 31     Male
# 32   Female
# 33   Female
# 34   Female
# 35    Group
# 36  Unknown
# 37    Group
# 38     Male
# 39     Male
# 40     Male
# 41   Female
# 42     Male
# 43    Group
# 44     Male
# 45  Unknown
# 46  Unknown
# 47     Male
# 48     Male
# 49  Unknown
# 50    Group
# 51     Male
# 52    Group
# 53     Male
# 54    Group
# 55   Female
# 56     Male
# 57    Group
# 58     Male
# 59     Male
# 60     Male
# 61     Male
# 62  Unknown
# 63    Group
# 64     Male
# 65     Male
# 66     Male
# 67     Male
# 68     Male
# 69  Unknown
# 70   Female
# 71    Group
# 72   Female
# 73     Male
# 74     Male
# 75     Male
# 76     Male
# 77   Female
# 78  Unknown
# 79     Male
# 80     Male
# 81  Unknown
# 82  Unknown
# 83    Group
# 84     Male
# 85     Male
# 86     Male
# 87     Male
# 88     Male
# 89   Female
# 90  Unknown
# 91    Group
# 92     Male
# 93    Group
# 94    Group
# 95     Male
# 96  Unknown
# 97   Female
# 98  Unknown
# 99    Group
